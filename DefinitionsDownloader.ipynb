# %%
import requests
import time
from bs4 import BeautifulSoup
import string

# %%
words = """
a waste of time
get distracted
twice a week
Clumsy
Hug
Quite ready
Watch over
Harm
There is no doubt
Prayer
Gloomy
Poverty
Beside
revere
admire
intricate
despite
siege
crucially
argue
Wicked
Quarrel
Pit
Waistcoat
Crowd
Crowded
Worship
Suddenly
Rush
Pillar
Worthy
Procreate
spreadsheet
integer
odd
even
revise
Excitement
Engagement
"""

# %%
words_list = [l.lower() for l in words.split('\n') if l.strip()]

# %%
def get_definitions(word, session=None, dictionary='english'):
  print(f"Getting info for {word} from {dictionary} dictionary.")

  url = f"https://dictionary.cambridge.org/dictionary/{dictionary}/{word.replace(' ', '-')}"

  if session is None:
    req = requests
  else:
    req = session
  headers = {
      "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
      "Accept-Encoding": "gzip, deflate, br",
      "Accept-Language": "ru-RU,ru;q=0.8,en-US;q=0.5,en;q=0.3",
      "Cache-Control": "max-age=0",
      "Connection": "keep-alive",
      "Host": "dictionary.cambridge.org",
      "User-Agent": "Mozilla/5.0 (X11; Linux x86_64; rv:78.0) Gecko/20100101 Firefox/78.0",
  }
  response = req.get(url, headers=headers)

  if response.status_code != 200 or response.url == "https://dictionary.cambridge.org/dictionary/english/":
    return []

  html = response.content.decode('utf-8')
  soup = BeautifulSoup(html)

  meanings = soup.find_all("div", class_="pr dsense ")
  meanings.extend(soup.find_all("div", class_="pr dsense dsense-noh"))

  print(f"{word} has {len(meanings)} meanings.")

  definitions = []

  for mean in meanings:
    try:
      definition = mean.find("div", class_="def ddef_d db").get_text().strip().capitalize()
      if definition[-1] in string.punctuation:
        definition = definition[:-1] + '.'
      else:
        definition += '.'
      definitions.append(definition)
    except Exception as e: 
      print(e)

  return definitions

def get_card(word, session=None):
  definitions = get_definitions(word, session)

  if len(definitions) == 0:
    return False, f"{word}\nPLEASE, FIND THIS INFO MANUALLY"

  results = []
  
  for definition in definitions:
    results.append(f"{word}\n{definition}")
  
  return True, "\n\n".join(results)

# %%
def get_cards(words_list=[]):
  good_info = ""
  bad_info = ""
  session = requests.Session()
  for word in words_list:
    success, card = get_card(word, session)
    if success:
      good_info += card + "\n\n"
    else:
      bad_info += card + "\n\n"
    time.sleep(3)
  return good_info + "\n\n" + bad_info

# %%
cards = get_cards(words_list)
print('\n\n\n')
print('Result:')
print('\n\n\n')
print(cards)
# Out:
# Getting info for a waste of time from english dictionary.
# Getting info for get distracted from english dictionary.
# Getting info for twice a week from english dictionary.
# Getting info for clumsy from english dictionary.
# clumsy has 2 meanings.
# Getting info for hug from english dictionary.
# hug has 3 meanings.
# Getting info for quite ready from english dictionary.
# Getting info for watch over from english dictionary.
# watch over has 1 meanings.
# Getting info for harm from english dictionary.
# harm has 6 meanings.
# Getting info for there is no doubt from english dictionary.
# Getting info for prayer from english dictionary.
# prayer has 2 meanings.
# Getting info for gloomy from english dictionary.
# gloomy has 5 meanings.
# Getting info for poverty from english dictionary.
# poverty has 3 meanings.
# Getting info for beside from english dictionary.
# beside has 2 meanings.
# Getting info for revere from english dictionary.
# revere has 2 meanings.
# Getting info for admire from english dictionary.
# admire has 2 meanings.
# Getting info for intricate from english dictionary.
# intricate has 2 meanings.
# Getting info for despite from english dictionary.
# despite has 2 meanings.
# Getting info for siege from english dictionary.
# siege has 2 meanings.
# Getting info for crucially from english dictionary.
# crucially has 1 meanings.
# Getting info for argue from english dictionary.
# argue has 5 meanings.
# Getting info for wicked from english dictionary.
# wicked has 3 meanings.
# Getting info for quarrel from english dictionary.
# quarrel has 0 meanings.
# Getting info for pit from english dictionary.
# pit has 9 meanings.
# Getting info for waistcoat from english dictionary.
# waistcoat has 1 meanings.
# Getting info for crowd from english dictionary.
# crowd has 4 meanings.
# Getting info for crowded from english dictionary.
# crowded has 2 meanings.
# Getting info for worship from english dictionary.
# worship has 8 meanings.
# Getting info for suddenly from english dictionary.
# suddenly has 2 meanings.
# Getting info for rush from english dictionary.
# rush has 14 meanings.
# Getting info for pillar from english dictionary.
# pillar has 2 meanings.
# Getting info for worthy from english dictionary.
# worthy has 6 meanings.
# Getting info for procreate from english dictionary.
# procreate has 2 meanings.
# Getting info for spreadsheet from english dictionary.
# spreadsheet has 2 meanings.
# Getting info for integer from english dictionary.
# integer has 2 meanings.
# Getting info for odd from english dictionary.
# odd has 9 meanings.
# Getting info for even from english dictionary.
# even has 19 meanings.
# Getting info for revise from english dictionary.
# revise has 6 meanings.
# Getting info for excitement from english dictionary.
# excitement has 1 meanings.
# Getting info for engagement from english dictionary.
# engagement has 10 meanings.
#
#
#
#
# Result:
#
#
#
#
# clumsy
# A clumsy person often has accidents because they do not behave in a careful, controlled way.
#
# clumsy
# Awkward in movement or manner.
#
# hug
# To hold someone close to your body with your arms, usually to show that you like, love, or value them.
#
# hug
# The act of holding someone or something close to your body with your arms.
#
# hug
# To hold someone or something close to your body with your arms, esp. to show affection.
#
# watch over
# To protect someone and make certain that they are safe.
#
# harm
# Physical or other injury or damage.
#
# harm
# To hurt someone or damage something.
#
# harm
# Physical or other injury or damage.
#
# harm
# Damage done to something.
#
# harm
# Used to say that an action is not helpful and could make a situation worse.
#
# harm
# To damage something or make something worse.
#
# prayer
# The words that someone says or thinks when they are praying.
#
# prayer
# The act or ceremony of speaking to god or a god, esp. to express thanks or to ask for help, or the words used in this act.
#
# gloomy
# Unhappy and without hope.
#
# gloomy
# Dark in a way that is unpleasant and makes it difficult to see.
#
# gloomy
# Having or showing a lack of hope.
#
# gloomy
# Dark or nearly dark.
#
# gloomy
# Not giving much hope for the future.
#
# poverty
# The condition of being extremely poor.
#
# poverty
# The condition of being poor.
#
# poverty
# The condition of being extremely poor.
#
# beside
# At the side of, next to.
#
# beside
# At the side of; next to.
#
# revere
# To very much respect and admire someone or something.
#
# revere
# To greatly respect and admire someone or something.
#
# admire
# To find someone or something attractive and pleasant to look at.
#
# admire
# To respect and approve of someone or something.
#
# intricate
# Having a lot of small parts that are arranged in a complicated or delicate way.
#
# intricate
# Having a lot of small parts or pieces arranged in a complicated way, and therefore sometimes difficult to understand in detail.
#
# despite
# Without taking any notice of or being influenced by; not prevented by.
#
# despite
# Without being influenced or prevented by.
#
# siege
# The surrounding of a place by an armed force in order to defeat those defending it.
#
# siege
# The act of surrounding a place by an armed force in order to defeat those defending it.
#
# crucially
# In a way that is extremely important or necessary.
#
# argue
# To speak angrily to someone, telling that person that you disagree with them.
#
# argue
# To give the reasons for your opinion, idea, belief, etc..
#
# argue
# To show that something is true or exists.
#
# argue
# To disagree esp. strongly and sometimes angrily in talking or discussing something.
#
# argue
# To give the reasons for your opinion about the truth of something or to explain why you believe something should be done.
#
# wicked
# Morally wrong and bad.
#
# wicked
# Excellent.
#
# wicked
# Morally wrong and bad.
#
# pit
# A large hole in the ground, or a slightly low area in any surface.
#
# pit
# A large, hard seed inside some types of fruit.
#
# pit
# A large hole in the ground, or a hollow in any surface.
#
# pit
# A large, hard seed that grows inside some types of fruit and vegetables.
#
# pit
# An area on the side of a track on which cars race, where the cars are given fuel or repaired during a race.
#
# pit
# A hole from which natural substances, such as rocks and minerals, are dug; mine.
#
# pit
# Us for
# stone.
#
# pit
# The area of a stock exchange used for trading.
#
# pit
# A deep area underground from which a natural resource is taken by digging.
#
# waistcoat
# A piece of clothing that covers the upper body but not the arms and usually has buttons down the front, worn over a shirt.
#
# crowd
# A large group of people who have come together.
#
# crowd
# To make someone feel uncomfortable by standing too close to them or by watching them all the time.
#
# crowd
# A large group of people who have gathered together.
#
# crowd
# (of people) to fill a place.
#
# crowded
# If a place is crowded, it is full of people.
#
# crowded
# Full of people.
#
# worship
# To have or show a strong feeling of respect and admiration for god or a god.
#
# worship
# To love, respect, and admire someone or something very much, often without noticing the bad qualities of that person or thing.
#
# worship
# The act of worshipping god or a god, often through praying or singing.
#
# worship
# A lot of love or admiration for a particular thing or person, often when this is considered too much.
#
# worship
# Used as a title of respect when speaking to or about a mayor or a magistrate.
#
# worship
# To pray to god or a god.
#
# worship
# To feel a lot of love and admiration for someone or something.
#
# worship
# A house/place of worship is a building for religious ceremonies and prayer.
#
# suddenly
# Quickly and unexpectedly.
#
# suddenly
# In a sudden way; very quickly or unexpectedly.
#
# rush
# To (cause to) go or do something very quickly.
#
# rush
# If a group of people rush an enemy or the place where an enemy is, they attack suddenly and all together.
#
# rush
# In american football, to rush is to carry the ball forward across the place on the field where play begins. also, a member of the opposite team rushes when they force their way to the back of the field quickly to catch the player carrying the ball.
#
# rush
# A situation in which you have to hurry or move somewhere quickly.
#
# rush
# A sudden strong emotion or physical feeling.
#
# rush
# A plant like grass that grows in or near water and whose long, thin, hollow stems can be dried and made into floor coverings, containers, etc..
#
# rush
# To do something or move very quickly, or to cause someone to act in such a way; hurry.
#
# rush
# Something moving quickly, or the need for quick action.
#
# rush
# To move or go somewhere very quickly.
#
# rush
# To do something very quickly.
#
# rush
# The state of hurrying somewhere.
#
# rush
# A time when a lot of people are leaving one place and going to another, for example leaving work to go to lunch, go home, etc..
#
# rush
# A time when many people try to buy something.
#
# rush
# A sudden movement towards something.
#
# pillar
# A strong column made of stone, metal, or wood that supports part of a building.
#
# pillar
# A strong vertical column made of stone, metal, or wood that supports part of a building or stands alone for decoration.
#
# worthy
# Deserving respect, admiration, or support.
#
# worthy
# Suitable for or characteristic of something.
#
# worthy
# Deserving respect, admiration, or support.
#
# worthy
# Deserving or suitable for.
#
# worthy
# A person who is important, especially in a small town.
#
# worthy
# Suitable or deserving to receive a particular thing.
#
# procreate
# To produce young.
#
# procreate
# To reproduce sexually.
#
# spreadsheet
# An electronic document in which information is arranged in rows and columns, and can be used to do financial calculations and plans.
#
# spreadsheet
# A piece of computer software used for showing rows and columns of numbers or other data, and for doing calculations with this data.
#
# integer
# A whole number and not a fraction.
#
# integer
# A whole number and not a fraction.
#
# odd
# Strange or unexpected.
#
# odd
# Not happening often.
#
# odd
# (of numbers) not able to be divided exactly by two.
#
# odd
# (of something that should be in a pair or set) separated from its pair or set.
#
# odd
# Strange or unexpected.
#
# odd
# (of something that should be in a pair or set) separated from its pair or set.
#
# odd
# (of numbers) not able to be divided exactly by 2.
#
# odd
# Used after a number, esp. a number that can be divided by 10, to show that the exact number is not known.
#
# odd
# Used after a number, especially a number that can be divided by ten, to show that the exact number is not known.
#
# even
# Used to show that something is surprising, unusual, unexpected, or extreme.
#
# even
# Used to emphasize a comparison.
#
# even
# Used when you want to be more exact or detailed about something you have just said.
#
# even
# Flat and smooth, or on the same level.
#
# even
# Continuous or regular.
#
# even
# Equal or equally balanced.
#
# even
# Forming a whole number that can be divided exactly by two.
#
# even
# Equal or equally balanced.
#
# even
# Continuous or regular.
#
# even
# Flat and smooth, or on the same level.
#
# even
# (of numbers) able to be exactly divided by two.
#
# even
# Used to emphasize a comparison or the unexpected or extreme characteristic of something.
#
# even
# Used when you want to be more exact or detailed about something you have just said.
#
# even
# To make equal.
#
# even
# To make two things equal.
#
# even
# Happening in a smooth, gradual, and regular way instead of changing a lot or changing suddenly.
#
# even
# Fair and equal.
#
# even
# Used to describe a number that ends in 0, not more or less than that number.
#
# even
# Able to stay even and regular, and not change suddenly.
#
# revise
# To look at or consider again an idea, piece of writing, etc. in order to correct or improve it.
#
# revise
# To study again something you have already learned, in preparation for an exam.
#
# revise
# To change or correct something, esp. a piece of writing.
#
# revise
# To change an amount or value in order to make it more accurate.
#
# revise
# To make changes to a plan, system, or law in order to improve it.
#
# revise
# To make changes to a book, document, etc. in order to improve it, correct mistakes, or make it contain the most recent information.
#
# excitement
# A feeling of being excited, or an exciting event.
#
# engagement
# An agreement to marry someone.
#
# engagement
# An arrangement to meet someone or do something at a particular time.
#
# engagement
# The act of beginning to fight someone, or a period of time in a war.
#
# engagement
# The fact of being involved with something.
#
# engagement
# An arrangement to do something or meet someone at a particular time and place.
#
# engagement
# The act of beginning to fight someone, or a period of time in a war.
#
# engagement
# The act of promising that you intend to marry, or the state of having decided to get married.
#
# engagement
# An arrangement to do something, or to be somewhere.
#
# engagement
# The fact of employing someone.
#
# engagement
# Used to show that something, for example a price, can be changed.
#
#
#
# a waste of time
# PLEASE, FIND THIS INFO MANUALLY
#
# get distracted
# PLEASE, FIND THIS INFO MANUALLY
#
# twice a week
# PLEASE, FIND THIS INFO MANUALLY
#
# quite ready
# PLEASE, FIND THIS INFO MANUALLY
#
# there is no doubt
# PLEASE, FIND THIS INFO MANUALLY
#
# quarrel
# PLEASE, FIND THIS INFO MANUALLY
